# %%
! pip install langchain unstructured[all-docs] pydantic lxml langchainhub langchain_openai
# Out:
# Requirement already satisfied: langchain in ./.venv/lib/python3.10/site-packages (0.1.17)
# Requirement already satisfied: unstructured[all-docs] in ./.venv/lib/python3.10/site-packages (0.13.6)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: lxml in ./.venv/lib/python3.10/site-packages (5.2.1)
# Requirement already satisfied: langchainhub in ./.venv/lib/python3.10/site-packages (0.1.15)
# Requirement already satisfied: langchain_openai in ./.venv/lib/python3.10/site-packages (0.1.6)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in ./.venv/lib/python3.10/site-packages (from langchain) (0.1.52)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./.venv/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.10/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in ./.venv/lib/python3.10/site-packages (from langchain) (0.0.37)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.10/site-packages (from langchain) (1.33)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.10/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: numpy<2,>=1 in ./.venv/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./.venv/lib/python3.10/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in ./.venv/lib/python3.10/site-packages (from langchain) (0.0.1)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./.venv/lib/python3.10/site-packages (from langchain) (0.1.54)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.10/site-packages (from langchain) (0.6.5)
# Requirement already satisfied: rapidfuzz in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.9.0)
# Requirement already satisfied: filetype in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: emoji in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (2.11.1)
# Requirement already satisfied: tabulate in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: backoff in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (2.2.1)
# Requirement already satisfied: python-magic in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.4.27)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: langdetect in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.0.9)
# Requirement already satisfied: unstructured-client in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.22.0)
# Requirement already satisfied: python-iso639 in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (2024.4.27)
# Requirement already satisfied: nltk in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (4.11.0)
# Requirement already satisfied: chardet in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (5.2.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (4.12.3)
# Requirement already satisfied: msg-parser in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.2.0)
# Requirement already satisfied: pypdf in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (4.2.0)
# Requirement already satisfied: openpyxl in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (2.2.2)
# Requirement already satisfied: unstructured-inference==0.7.29 in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.7.29)
# Requirement already satisfied: python-docx in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.1.2)
# Requirement already satisfied: onnx in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: python-pptx<=0.6.23 in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.6.23)
# Requirement already satisfied: pdfminer.six in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (20231228)
# Requirement already satisfied: markdown in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.6)
# Requirement already satisfied: pdf2image in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.17.0)
# Requirement already satisfied: google-cloud-vision in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.7.2)
# Requirement already satisfied: pikepdf in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (8.15.1)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (3.3)
# Requirement already satisfied: pillow-heif in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.16.0)
# Requirement already satisfied: unstructured.pytesseract>=0.3.12 in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (0.3.12)
# Requirement already satisfied: pypandoc in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (1.13)
# Requirement already satisfied: xlrd in ./.venv/lib/python3.10/site-packages (from unstructured[all-docs]) (2.0.1)
# Requirement already satisfied: huggingface-hub in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.23.0)
# Requirement already satisfied: python-multipart in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.0.9)
# Requirement already satisfied: transformers>=4.25.1 in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (4.40.2)
# Requirement already satisfied: onnxruntime>=1.17.0 in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (1.17.3)
# Requirement already satisfied: opencv-python!=4.7.0.68 in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (4.9.0.80)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in ./.venv/lib/python3.10/site-packages (from unstructured-inference==0.7.29->unstructured[all-docs]) (0.3.4)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in ./.venv/lib/python3.10/site-packages (from pydantic) (2.18.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in ./.venv/lib/python3.10/site-packages (from langchainhub) (2.31.0.20240406)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in ./.venv/lib/python3.10/site-packages (from langchain_openai) (0.6.0)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in ./.venv/lib/python3.10/site-packages (from langchain_openai) (1.26.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.2)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in ./.venv/lib/python3.10/site-packages (from langchain-core<0.2.0,>=0.1.48->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (0.27.0)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.66.4)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.3.1)
# Requirement already satisfied: Pillow>=3.3.2 in ./.venv/lib/python3.10/site-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (10.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in ./.venv/lib/python3.10/site-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./.venv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.10/site-packages (from tiktoken<1,>=0.5.2->langchain_openai) (2024.4.28)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./.venv/lib/python3.10/site-packages (from google-cloud-vision->unstructured[all-docs]) (1.23.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in ./.venv/lib/python3.10/site-packages (from google-cloud-vision->unstructured[all-docs]) (2.29.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in ./.venv/lib/python3.10/site-packages (from google-cloud-vision->unstructured[all-docs]) (2.19.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in ./.venv/lib/python3.10/site-packages (from google-cloud-vision->unstructured[all-docs]) (4.25.3)
# Requirement already satisfied: six in ./.venv/lib/python3.10/site-packages (from langdetect->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: olefile>=0.46 in ./.venv/lib/python3.10/site-packages (from msg-parser->unstructured[all-docs]) (0.47)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from nltk->unstructured[all-docs]) (8.1.7)
# Requirement already satisfied: joblib in ./.venv/lib/python3.10/site-packages (from nltk->unstructured[all-docs]) (1.4.2)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.10/site-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->unstructured[all-docs]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in ./.venv/lib/python3.10/site-packages (from pdfminer.six->unstructured[all-docs]) (42.0.7)
# Requirement already satisfied: Deprecated in ./.venv/lib/python3.10/site-packages (from pikepdf->unstructured[all-docs]) (1.2.14)
# Requirement already satisfied: deepdiff>=6.0 in ./.venv/lib/python3.10/site-packages (from unstructured-client->unstructured[all-docs]) (7.0.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in ./.venv/lib/python3.10/site-packages (from unstructured-client->unstructured[all-docs]) (1.0.6)
# Requirement already satisfied: mypy-extensions>=1.0.0 in ./.venv/lib/python3.10/site-packages (from unstructured-client->unstructured[all-docs]) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain_openai) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in ./.venv/lib/python3.10/site-packages (from deepdiff>=6.0->unstructured-client->unstructured[all-docs]) (4.1.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.63.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.62.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in ./.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.63.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.10/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai) (0.14.0)
# Requirement already satisfied: flatbuffers in ./.venv/lib/python3.10/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: coloredlogs in ./.venv/lib/python3.10/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (15.0.1)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (1.12)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (3.14.0)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.venv/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.29->unstructured[all-docs]) (0.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.10/site-packages (from huggingface-hub->unstructured-inference==0.7.29->unstructured[all-docs]) (2024.3.1)
# Requirement already satisfied: pdfplumber in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.11.0)
# Requirement already satisfied: iopath in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.1.10)
# Requirement already satisfied: scipy in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (1.13.0)
# Requirement already satisfied: pytesseract in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.3.10)
# Requirement already satisfied: torch in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.2.2)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.17.2)
# Requirement already satisfied: effdet in ./.venv/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.4.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./.venv/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (10.0)
# Requirement already satisfied: timm>=0.9.2 in ./.venv/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.9.16)
# Requirement already satisfied: omegaconf>=2.0 in ./.venv/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.3.0)
# Requirement already satisfied: pycocotools>=2.0.2 in ./.venv/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.0.7)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (3.1.4)
# Requirement already satisfied: portalocker in ./.venv/lib/python3.10/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.8.2)
# Requirement already satisfied: pypdfium2>=4.18.0 in ./.venv/lib/python3.10/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.29.0)
# Requirement already satisfied: mpmath>=0.19 in ./.venv/lib/python3.10/site-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.29->unstructured[all-docs]) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in ./.venv/lib/python3.10/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in ./.venv/lib/python3.10/site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (3.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (2.1.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (4.51.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.29->unstructured[all-docs]) (0.12.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from typing import Any

from pydantic import BaseModel
from unstructured.partition.pdf import partition_pdf

# Get elements
raw_pdf_elements = partition_pdf(
    filename="protocol.pdf",
    # extract_images_in_pdf=False,
    # # # Use layout model (YOLOX) to get bounding boxes (for tables) and find titles
    # # # Titles are any sub-section of the document
    infer_table_structure=True,
    # # Post processing to aggregate text once we have the title
    chunking_strategy="by_title",
)
# Out:
# This function will be deprecated in a future release and `unstructured` will simply use the DEFAULT_MODEL from `unstructured_inference.model.base` to set default model name

# %%
# Create a dictionary to store counts of each type
category_counts = {}

for element in raw_pdf_elements:
    category = str(type(element))
    if category in category_counts:
        category_counts[category] += 1
    else:
        category_counts[category] = 1

# Unique_categories will have unique elements
unique_categories = set(category_counts.keys())
category_counts
# Out:
# {"<class 'unstructured.documents.elements.CompositeElement'>": 902,
#  "<class 'unstructured.documents.elements.Table'>": 5,
#  "<class 'unstructured.documents.elements.TableChunk'>": 204}

# %%
class Element(BaseModel):
    type: str
    text: Any


# Categorize by type
categorized_elements = []
for element in raw_pdf_elements:
    if "unstructured.documents.elements.Table" in str(type(element)):
        categorized_elements.append(Element(type="table", text=str(element)))
    elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
        categorized_elements.append(Element(type="text", text=str(element)))

# Tables
table_elements = [e for e in categorized_elements if e.type == "table"]

# Text
text_elements = [e for e in categorized_elements if e.type == "text"]

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# Prompt
prompt_text = """You are an assistant tasked with summarizing tables and text. \ 
Give a concise summary of the table or text. Table or text chunk: {element} """
prompt = ChatPromptTemplate.from_template(prompt_text)

# Summary chain
model = ChatOpenAI(temperature=0, model="gpt-3.5-turbo")
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

# Apply to tables
tables = [i.text for i in table_elements]
table_summaries = summarize_chain.batch(tables, {"max_concurrency": 5})
# Apply to texts
texts = [i.text for i in text_elements]
text_summaries = summarize_chain.batch(texts, {"max_concurrency": 5})

# %%
import uuid

from langchain.retrievers.multi_vector import MultiVectorRetriever
from langchain.storage import InMemoryStore
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings

# The vectorstore to use to index the child chunks
vectorstore = Chroma(collection_name="summaries", embedding_function=OpenAIEmbeddings())

# The storage layer for the parent documents
store = InMemoryStore()
id_key = "doc_id"

# The retriever (empty to start)
retriever = MultiVectorRetriever(
    vectorstore=vectorstore,
    docstore=store,
    id_key=id_key,
)

# Add texts
doc_ids = [str(uuid.uuid4()) for _ in texts]
summary_texts = [
    Document(page_content=s, metadata={id_key: doc_ids[i]})
    for i, s in enumerate(text_summaries)
]
retriever.vectorstore.add_documents(summary_texts)
retriever.docstore.mset(list(zip(doc_ids, texts)))

# Add tables
table_ids = [str(uuid.uuid4()) for _ in tables]
summary_tables = [
    Document(page_content=s, metadata={id_key: table_ids[i]})
    for i, s in enumerate(table_summaries)
]
retriever.vectorstore.add_documents(summary_tables)
retriever.docstore.mset(list(zip(table_ids, tables)))

# %%
from langchain_core.runnables import RunnablePassthrough

# Prompt template
template = """Answer the question based only on the following context, which can include text and tables:
{context}
Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)

# LLM
model = ChatOpenAI(temperature=0, model="gpt-4")

# RAG pipeline
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
# chain.invoke("What cars did Craig Breedlove drove?")
chain.invoke("What is the tapering regimen for 'Budesonide and beclomethasone dipropionate'")
# Out:
# 'The tapering regimen for Budesonide and beclomethasone dipropionate is to have their daily dose tapered according to local clinical practice until 0 mg/day.'
